# %% [markdown]
# # ANNDL CHALLENGE 2

# %% [markdown]
# ## Set up envoironment

# %% [markdown]
# ### Set up Google Drive

# %%
from google.colab import drive
drive.mount('/gdrive')
# %cd /gdrive/MyDrive/ANNDL/Challenge2
# Out:
# Mounted at /gdrive
# /gdrive/.shortcut-targets-by-id/1wYXyoEwRqU1umxccIJJH4SamZKzkPV7x/ANNDL/Challenge2

# %% [markdown]
# ### Import libraries

# %%
import sys
sys.path.append('Federico')

# %%
from utils import augmentation as aug
import tensorflow as tf
import numpy as np
import os
import random
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
plt.rc('font', size=16) 
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score
from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import StandardScaler
from sklearn.utils import shuffle
import warnings
import logging

tfk = tf.keras
tfkl = tf.keras.layers
print(tf.__version__)
# Out:
# 2.9.2

# %% [markdown]
# ### Set seed reproducibility

# %%
# Random seed for reproducibility
seed = 42

random.seed(seed)
os.environ['PYTHONHASHSEED'] = str(seed)
np.random.seed(seed)
tf.random.set_seed(seed)
tf.compat.v1.set_random_seed(seed)

# %% [markdown]
# ## Data loading

# %%
#Data loading
x = np.load('/gdrive/MyDrive/ANNDL/Challenge2/training_dataset_homework2/x_train.npy')
y = np.load('/gdrive/MyDrive/ANNDL/Challenge2/training_dataset_homework2/y_train.npy')

# %%
#Dimension of the data 
print('n =', x.shape[0], ' timestamps =', x.shape[1], 'features =', x.shape[2])
# Out:
# n = 2429  timestamps = 36 features = 6

# %% [markdown]
# ###Inspect the dataset

# %%
from collections import Counter
Counter(y)
# Out:
# Counter({0: 34,
#          1: 123,
#          2: 270,
#          3: 381,
#          4: 62,
#          5: 153,
#          6: 313,
#          7: 68,
#          8: 120,
#          9: 777,
#          10: 77,
#          11: 51})

# %%
grade_distribution_y = {'0': x[:,35,0],'1': x[:,35,1],'2': x[:,35,2],'3': x[:,35,3],'4': x[:,35,4],'5': x[:,35,5],
                        'classes': y }   
df_y = pd.DataFrame(grade_distribution_y, columns = ['0','1','2','3','4','5','classes'])
print(df_y)
# Out:
#              0        1         2          3          4          5  classes
# 0     43.71900  30.6890  950.9200  859.27000  8133.1000  988.83000        0
# 1     -4.63520  -3.2769   -5.9048   -0.19564     1.1487   23.27500        0
# 2     12.55700   2.2734    4.4831  -12.88500    10.4880  -66.96000        0
# 3      4.48520   2.4419   -2.2354   -0.31232    -5.0553  -32.70000        0
# 4     -1.68130  40.5160  -72.2560 -122.61000    20.3510  -87.72900        0
# ...        ...      ...       ...        ...        ...        ...      ...
# 2424 -16.19600   7.4568   19.1400   21.01600    31.0340   78.30600       11
# 2425   4.62530   1.0230    4.1203    2.52420    30.1710   30.37800       11
# 2426  -0.72203   2.8672    6.6811   13.44000    17.8740   27.19300       11
# 2427   5.93960   2.3820   13.2110   18.60300    33.1230    0.44679       11
# 2428  -1.55450  -1.2121    1.0705    1.32720     2.4010    8.45500       11
#
# [2429 rows x 7 columns]

# %%
# Inspect classes  
plt.figure(figsize=(17,5))
sns.countplot(x = 'classes', data = df_y, order = df_y.classes.value_counts().index)
plt.show()

# %%
#create a dataframe for each n
def create_df(n):
  grade_distribution_0 = {'0': x[n,:,0],'1': x[n,:,1],'2': x[n,:,2],'3': x[n,:,3],'4': x[n,:,4],'5': x[n,:,5]}
        #'classes': y }   
  df = pd.DataFrame(grade_distribution_0, columns = ['0','1','2','3','4','5'])
  return df

# %%
def inspect_activity(df):     #(classes, df):
    data = df[['0','1','2','3','4','5']][:100]
    axis = data.plot(subplots=True, figsize=(17, 9)) # title=classes)
    for ax in axis:
        ax.legend(loc='lower right')

# %%
inspect_activity(create_df(1)) #timeseries at n = 1

# %% [markdown]
# ## Train test split

# %%
# Split the dataset into training set and test set
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

# %%
#Data augmentation using an external library 
x_train = np.append(x_train, aug.random_guided_warp(x_train, y_train), axis=0)
y_train = np.append(y_train, y_train, axis=0)

print(x_train.shape)
print(y_train.shape)

# Shuffle the indexes
x_train, y_train = shuffle(x_train, y_train)
# Out:
# 100%|██████████| 1943/1943 [00:02<00:00, 734.67it/s]
# (3886, 36, 6)
# (3886,)

# %%
# Data augmentation: shift the order of timestamps in each sample and add a random noise

N = x_train.shape[0]        # Number of samples
T = x_train.shape[1]        # Number of timestamps
F = x_train.shape[2]        # Number of features

new_train_1 = np.zeros((N, T, F))   
step = int(T/2)

for i in np.arange(0,N):
  for j in range(0,F): 
    
    new_train_1[i,0:step,j] = x_train[i,-step:,j] + np.random.standard_normal(step)
    new_train_1[i,-step:,j] = x_train[i,0:step,j] + np.random.standard_normal(step)

x_newtrain = np.zeros((2*N, T, F))
x_newtrain[0:N,:,:] = x_train
x_newtrain[N:2*N,:,:] = new_train_1
x_newtrain.shape
# Out:
# (7772, 36, 6)

# %%
#Append the new labels on the dataset
y_newtrain = np.zeros(2*y_train.shape[0])
y_newtrain[0:y_train.shape[0]] = y_train
y_newtrain[y_train.shape[0]:2*y_train.shape[0]] = y_train
y_newtrain.shape
# Out:
# (7772,)

# %%
x_train = x_newtrain
y_train = y_newtrain

# %%
# Convert the sparse labels to categorical values
y_train = tfk.utils.to_categorical(y_train)
y_test = tfk.utils.to_categorical(y_test)

# %% [markdown]
# ###Correlation between the features

# %%
A = x.copy()

names = ['x', 'y', 'z']

index = pd.MultiIndex.from_product([range(s)for s in A.shape], names=names)
df = pd.DataFrame({'A': A.flatten()}, index=index)['A']
df = df.unstack(level='z').swaplevel().sort_index()

columns = []

for i in range(6):
  columns.append(str(i+1))

df.columns = columns
df.index.names = ['Second', 'i']

sns.heatmap(df.corr(), annot=True)
plt.show()

# %% [markdown]
# ### Parameters

# %%
# Set the parameters
input_shape = x_train.shape[1:]
classes = y_train.shape[-1]
batch_size = 192
epochs = 600
print('epochs =', epochs, ' batch_size =', batch_size, 'classes =', classes)
# Out:
# epochs = 600  batch_size = 192 classes = 12

# %% [markdown]
# ###Build and train the model

# %%
def model_1D_CNN(input_shape, classes):
    # Build the neural network layer by layer

    input_layer = tfkl.Input(shape=input_shape, name='Input')
  
    # Feature extractor
    cnn_1 = tfkl.Conv1D(128,2,padding='same',activation='relu')(input_layer)  
    cnn_2 = tfkl.AveragePooling1D(name = 'AveragePooling1D_1')(cnn_1)
    dropout = tfkl.Dropout(.2, seed=seed)(cnn_2)
    cnn_3 = tfkl.Conv1D(256,2,padding='same',activation='relu')(dropout)       
    cnn_4 = tfkl.AveragePooling1D()(cnn_3)
    dropout = tfkl.Dropout(.2, seed=seed)(cnn_4)
    cnn_5 = tfkl.Conv1D(512,2,padding='same',activation='relu')(dropout)
    gap = tfkl.GlobalAveragePooling1D()(cnn_5)
    dropout = tfkl.Dropout(.2, seed=seed)(gap)

    # Classifier
    classifier = tfkl.Dense(256, activation='relu',kernel_regularizer = tf.keras.regularizers.l2(0.01))(dropout)   # Add a L2 regularization term with lambda = 0.01
    output_layer = tfkl.Dense(classes, activation='softmax')(classifier)

    # Connect input and output through the Model class
    model = tfk.Model(inputs=input_layer, outputs=output_layer, name='model')

    # Compile the model
    model.compile(loss=tfk.losses.CategoricalCrossentropy(), optimizer=tfk.optimizers.Adam(), metrics='accuracy')

    # Return the model
    return model

# %%
#Summary of the model
model = model_1D_CNN(input_shape, classes)
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Input (InputLayer)          [(None, 36, 6)]           0
#
#  conv1d_18 (Conv1D)          (None, 36, 128)           1664
#
#  AveragePooling1D_1 (Average  (None, 18, 128)          0
#  Pooling1D)
#
#  dropout_18 (Dropout)        (None, 18, 128)           0
#
#  conv1d_19 (Conv1D)          (None, 18, 256)           65792
#
#  average_pooling1d_12 (Avera  (None, 9, 256)           0
#  gePooling1D)
#
#  dropout_19 (Dropout)        (None, 9, 256)            0
#
#  conv1d_20 (Conv1D)          (None, 9, 512)            262656
#
#  global_average_pooling1d_6   (None, 512)              0
#  (GlobalAveragePooling1D)
#
#  dropout_20 (Dropout)        (None, 512)               0
#
#  dense_12 (Dense)            (None, 256)               131328
#
#  dense_13 (Dense)            (None, 12)                3084
#
# =================================================================
# Total params: 464,524
# Trainable params: 464,524
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Train the model
history = model.fit(
    x = x_train,
    y = y_train,
    batch_size = 192, 
    epochs = epochs,
    validation_split=.3,
    callbacks = [
        tfk.callbacks.EarlyStopping(monitor='val_accuracy', mode='max', patience=30, restore_best_weights=True),
        tfk.callbacks.ReduceLROnPlateau(monitor='val_accuracy', mode='max', patience=20, factor=0.2, min_lr=1e-6)
    ]
).history
# Out:
# Epoch 1/600
# 29/29 [==============================] - 1s 18ms/step - loss: 11.0921 - accuracy: 0.1842 - val_loss: 5.5736 - val_accuracy: 0.2719 - lr: 0.0010
# Epoch 2/600
# 29/29 [==============================] - 0s 10ms/step - loss: 5.3412 - accuracy: 0.3928 - val_loss: 4.9348 - val_accuracy: 0.4322 - lr: 0.0010
# Epoch 3/600
# 29/29 [==============================] - 0s 9ms/step - loss: 4.7688 - accuracy: 0.4349 - val_loss: 4.4833 - val_accuracy: 0.4974 - lr: 0.0010
# Epoch 4/600
# 29/29 [==============================] - 0s 8ms/step - loss: 4.3819 - accuracy: 0.4688 - val_loss: 4.1351 - val_accuracy: 0.4794 - lr: 0.0010
# Epoch 5/600
# 29/29 [==============================] - 0s 8ms/step - loss: 4.2079 - accuracy: 0.4803 - val_loss: 3.8869 - val_accuracy: 0.4850 - lr: 0.0010
# Epoch 6/600
# 29/29 [==============================] - 0s 9ms/step - loss: 3.9716 - accuracy: 0.4798 - val_loss: 3.6410 - val_accuracy: 0.5124 - lr: 0.0010
# Epoch 7/600
# 29/29 [==============================] - 0s 9ms/step - loss: 3.6187 - accuracy: 0.5206 - val_loss: 3.5189 - val_accuracy: 0.5197 - lr: 0.0010
# Epoch 8/600
# 29/29 [==============================] - 0s 8ms/step - loss: 3.6635 - accuracy: 0.4915 - val_loss: 3.3775 - val_accuracy: 0.5420 - lr: 0.0010
# Epoch 9/600
# 29/29 [==============================] - 0s 8ms/step - loss: 3.2852 - accuracy: 0.5265 - val_loss: 3.1138 - val_accuracy: 0.5772 - lr: 0.0010
# Epoch 10/600
# 29/29 [==============================] - 0s 8ms/step - loss: 3.1229 - accuracy: 0.5631 - val_loss: 2.9331 - val_accuracy: 0.5901 - lr: 0.0010
# Epoch 11/600
# 29/29 [==============================] - 0s 10ms/step - loss: 2.9630 - accuracy: 0.5772 - val_loss: 2.8023 - val_accuracy: 0.6021 - lr: 0.0010
# Epoch 12/600
# 29/29 [==============================] - 0s 9ms/step - loss: 2.8077 - accuracy: 0.5985 - val_loss: 2.6609 - val_accuracy: 0.6278 - lr: 0.0010
# Epoch 13/600
# 29/29 [==============================] - 0s 9ms/step - loss: 2.7132 - accuracy: 0.6187 - val_loss: 2.6961 - val_accuracy: 0.6021 - lr: 0.0010
# Epoch 14/600
# 29/29 [==============================] - 0s 9ms/step - loss: 2.7119 - accuracy: 0.5978 - val_loss: 2.5316 - val_accuracy: 0.6256 - lr: 0.0010
# Epoch 15/600
# 29/29 [==============================] - 0s 8ms/step - loss: 2.5180 - accuracy: 0.6230 - val_loss: 2.3926 - val_accuracy: 0.6411 - lr: 0.0010
# Epoch 16/600
# 29/29 [==============================] - 0s 9ms/step - loss: 2.4098 - accuracy: 0.6379 - val_loss: 2.3369 - val_accuracy: 0.6527 - lr: 0.0010
# Epoch 17/600
# 29/29 [==============================] - 0s 9ms/step - loss: 2.3320 - accuracy: 0.6412 - val_loss: 2.4424 - val_accuracy: 0.6042 - lr: 0.0010
# Epoch 18/600
# 29/29 [==============================] - 0s 9ms/step - loss: 2.3368 - accuracy: 0.6268 - val_loss: 2.1481 - val_accuracy: 0.6642 - lr: 0.0010
# Epoch 19/600
# 29/29 [==============================] - 0s 8ms/step - loss: 2.1735 - accuracy: 0.6509 - val_loss: 2.1014 - val_accuracy: 0.6368 - lr: 0.0010
# Epoch 20/600
# 29/29 [==============================] - 0s 10ms/step - loss: 2.0591 - accuracy: 0.6612 - val_loss: 1.9576 - val_accuracy: 0.6810 - lr: 0.0010
# Epoch 21/600
# 29/29 [==============================] - 0s 8ms/step - loss: 2.0856 - accuracy: 0.6506 - val_loss: 1.9841 - val_accuracy: 0.6565 - lr: 0.0010
# Epoch 22/600
# 29/29 [==============================] - 0s 8ms/step - loss: 1.9784 - accuracy: 0.6583 - val_loss: 1.8945 - val_accuracy: 0.6702 - lr: 0.0010
# Epoch 23/600
# 29/29 [==============================] - 0s 8ms/step - loss: 1.8857 - accuracy: 0.6680 - val_loss: 1.8497 - val_accuracy: 0.6690 - lr: 0.0010
# Epoch 24/600
# 29/29 [==============================] - 0s 8ms/step - loss: 1.8597 - accuracy: 0.6715 - val_loss: 1.8317 - val_accuracy: 0.6557 - lr: 0.0010
# Epoch 25/600
# 29/29 [==============================] - 0s 8ms/step - loss: 1.7780 - accuracy: 0.6754 - val_loss: 1.7488 - val_accuracy: 0.6775 - lr: 0.0010
# Epoch 26/600
# 29/29 [==============================] - 0s 9ms/step - loss: 1.8914 - accuracy: 0.6551 - val_loss: 1.7744 - val_accuracy: 0.6754 - lr: 0.0010
# Epoch 27/600
# 29/29 [==============================] - 0s 9ms/step - loss: 1.7245 - accuracy: 0.6730 - val_loss: 1.6615 - val_accuracy: 0.6784 - lr: 0.0010
# Epoch 28/600
# 29/29 [==============================] - 0s 10ms/step - loss: 1.8499 - accuracy: 0.6443 - val_loss: 1.8331 - val_accuracy: 0.6226 - lr: 0.0010
# Epoch 29/600
# 29/29 [==============================] - 0s 8ms/step - loss: 1.7650 - accuracy: 0.6570 - val_loss: 1.7000 - val_accuracy: 0.6574 - lr: 0.0010
# Epoch 30/600
# 29/29 [==============================] - 0s 8ms/step - loss: 1.6136 - accuracy: 0.6757 - val_loss: 1.5790 - val_accuracy: 0.6874 - lr: 0.0010
# Epoch 31/600
# 29/29 [==============================] - 0s 9ms/step - loss: 1.5363 - accuracy: 0.6923 - val_loss: 1.5106 - val_accuracy: 0.6917 - lr: 0.0010
# Epoch 32/600
# 29/29 [==============================] - 0s 9ms/step - loss: 1.5217 - accuracy: 0.6908 - val_loss: 1.4706 - val_accuracy: 0.6913 - lr: 0.0010
# Epoch 33/600
# 29/29 [==============================] - 0s 9ms/step - loss: 1.4853 - accuracy: 0.6971 - val_loss: 1.4935 - val_accuracy: 0.6857 - lr: 0.0010
# Epoch 34/600
# 29/29 [==============================] - 0s 8ms/step - loss: 1.4192 - accuracy: 0.7011 - val_loss: 1.4070 - val_accuracy: 0.6955 - lr: 0.0010
# Epoch 35/600
# 29/29 [==============================] - 0s 9ms/step - loss: 1.4190 - accuracy: 0.7013 - val_loss: 1.4321 - val_accuracy: 0.6900 - lr: 0.0010
# Epoch 36/600
# 29/29 [==============================] - 0s 8ms/step - loss: 1.4261 - accuracy: 0.7006 - val_loss: 1.3627 - val_accuracy: 0.6921 - lr: 0.0010
# Epoch 37/600
# 29/29 [==============================] - 0s 9ms/step - loss: 1.3400 - accuracy: 0.7081 - val_loss: 1.3192 - val_accuracy: 0.6960 - lr: 0.0010
# Epoch 38/600
# 29/29 [==============================] - 0s 9ms/step - loss: 1.2964 - accuracy: 0.7127 - val_loss: 1.2783 - val_accuracy: 0.7045 - lr: 0.0010
# Epoch 39/600
# 29/29 [==============================] - 0s 9ms/step - loss: 1.2583 - accuracy: 0.7127 - val_loss: 1.2300 - val_accuracy: 0.7118 - lr: 0.0010
# Epoch 40/600
# 29/29 [==============================] - 0s 9ms/step - loss: 1.2662 - accuracy: 0.7195 - val_loss: 1.3466 - val_accuracy: 0.6780 - lr: 0.0010
# Epoch 41/600
# 29/29 [==============================] - 0s 8ms/step - loss: 1.4912 - accuracy: 0.6743 - val_loss: 1.3518 - val_accuracy: 0.6840 - lr: 0.0010
# Epoch 42/600
# 29/29 [==============================] - 0s 9ms/step - loss: 1.4194 - accuracy: 0.6825 - val_loss: 1.4387 - val_accuracy: 0.6642 - lr: 0.0010
# Epoch 43/600
# 29/29 [==============================] - 0s 8ms/step - loss: 1.3320 - accuracy: 0.6849 - val_loss: 1.2461 - val_accuracy: 0.7041 - lr: 0.0010
# Epoch 44/600
# 29/29 [==============================] - 0s 9ms/step - loss: 1.3082 - accuracy: 0.6936 - val_loss: 1.2227 - val_accuracy: 0.7127 - lr: 0.0010
# Epoch 45/600
# 29/29 [==============================] - 0s 8ms/step - loss: 1.1992 - accuracy: 0.7131 - val_loss: 1.1807 - val_accuracy: 0.7114 - lr: 0.0010
# Epoch 46/600
# 29/29 [==============================] - 0s 9ms/step - loss: 1.2052 - accuracy: 0.7142 - val_loss: 1.3476 - val_accuracy: 0.6668 - lr: 0.0010
# Epoch 47/600
# 29/29 [==============================] - 0s 9ms/step - loss: 1.1639 - accuracy: 0.7219 - val_loss: 1.1268 - val_accuracy: 0.7157 - lr: 0.0010
# Epoch 48/600
# 29/29 [==============================] - 0s 9ms/step - loss: 1.1164 - accuracy: 0.7296 - val_loss: 1.1102 - val_accuracy: 0.7204 - lr: 0.0010
# Epoch 49/600
# 29/29 [==============================] - 0s 8ms/step - loss: 1.1171 - accuracy: 0.7265 - val_loss: 1.1117 - val_accuracy: 0.7226 - lr: 0.0010
# Epoch 50/600
# 29/29 [==============================] - 0s 8ms/step - loss: 1.1686 - accuracy: 0.7197 - val_loss: 1.0924 - val_accuracy: 0.7196 - lr: 0.0010
# Epoch 51/600
# 29/29 [==============================] - 0s 8ms/step - loss: 1.1027 - accuracy: 0.7246 - val_loss: 1.0610 - val_accuracy: 0.7273 - lr: 0.0010
# Epoch 52/600
# 29/29 [==============================] - 0s 8ms/step - loss: 1.0436 - accuracy: 0.7342 - val_loss: 1.0245 - val_accuracy: 0.7303 - lr: 0.0010
# Epoch 53/600
# 29/29 [==============================] - 0s 8ms/step - loss: 1.0190 - accuracy: 0.7436 - val_loss: 1.0371 - val_accuracy: 0.7307 - lr: 0.0010
# Epoch 54/600
# 29/29 [==============================] - 0s 9ms/step - loss: 1.0097 - accuracy: 0.7428 - val_loss: 1.0136 - val_accuracy: 0.7311 - lr: 0.0010
# Epoch 55/600
# 29/29 [==============================] - 0s 9ms/step - loss: 0.9784 - accuracy: 0.7430 - val_loss: 0.9713 - val_accuracy: 0.7371 - lr: 0.0010
# Epoch 56/600
# 29/29 [==============================] - 0s 8ms/step - loss: 0.9484 - accuracy: 0.7461 - val_loss: 0.9365 - val_accuracy: 0.7517 - lr: 0.0010
# Epoch 57/600
# 29/29 [==============================] - 0s 8ms/step - loss: 0.9859 - accuracy: 0.7465 - val_loss: 0.9654 - val_accuracy: 0.7410 - lr: 0.0010
# Epoch 58/600
# 29/29 [==============================] - 0s 9ms/step - loss: 0.9462 - accuracy: 0.7564 - val_loss: 0.9495 - val_accuracy: 0.7483 - lr: 0.0010
# Epoch 59/600
# 29/29 [==============================] - 0s 9ms/step - loss: 1.0125 - accuracy: 0.7366 - val_loss: 0.9497 - val_accuracy: 0.7530 - lr: 0.0010
# Epoch 60/600
# 29/29 [==============================] - 0s 8ms/step - loss: 0.9555 - accuracy: 0.7478 - val_loss: 0.9321 - val_accuracy: 0.7543 - lr: 0.0010
# Epoch 61/600
# 29/29 [==============================] - 0s 8ms/step - loss: 0.9101 - accuracy: 0.7614 - val_loss: 0.9141 - val_accuracy: 0.7504 - lr: 0.0010
# Epoch 62/600
# 29/29 [==============================] - 0s 9ms/step - loss: 0.8836 - accuracy: 0.7660 - val_loss: 0.8817 - val_accuracy: 0.7564 - lr: 0.0010
# Epoch 63/600
# 29/29 [==============================] - 0s 9ms/step - loss: 0.9325 - accuracy: 0.7596 - val_loss: 0.9212 - val_accuracy: 0.7491 - lr: 0.0010
# Epoch 64/600
# 29/29 [==============================] - 0s 9ms/step - loss: 0.9180 - accuracy: 0.7601 - val_loss: 0.8874 - val_accuracy: 0.7607 - lr: 0.0010
# Epoch 65/600
# 29/29 [==============================] - 0s 9ms/step - loss: 0.8564 - accuracy: 0.7719 - val_loss: 0.8677 - val_accuracy: 0.7573 - lr: 0.0010
# Epoch 66/600
# 29/29 [==============================] - 0s 8ms/step - loss: 0.8240 - accuracy: 0.7774 - val_loss: 0.8202 - val_accuracy: 0.7719 - lr: 0.0010
# Epoch 67/600
# 29/29 [==============================] - 0s 8ms/step - loss: 0.7935 - accuracy: 0.7833 - val_loss: 0.8308 - val_accuracy: 0.7727 - lr: 0.0010
# Epoch 68/600
# 29/29 [==============================] - 0s 9ms/step - loss: 0.7907 - accuracy: 0.7884 - val_loss: 0.8354 - val_accuracy: 0.7706 - lr: 0.0010
# Epoch 69/600
# 29/29 [==============================] - 0s 8ms/step - loss: 1.0109 - accuracy: 0.7463 - val_loss: 1.2286 - val_accuracy: 0.6981 - lr: 0.0010
# Epoch 70/600
# 29/29 [==============================] - 0s 9ms/step - loss: 1.2128 - accuracy: 0.7110 - val_loss: 1.1017 - val_accuracy: 0.7101 - lr: 0.0010
# Epoch 71/600
# 29/29 [==============================] - 0s 10ms/step - loss: 0.9957 - accuracy: 0.7452 - val_loss: 0.9792 - val_accuracy: 0.7337 - lr: 0.0010
# Epoch 72/600
# 29/29 [==============================] - 0s 9ms/step - loss: 1.0187 - accuracy: 0.7450 - val_loss: 0.9447 - val_accuracy: 0.7457 - lr: 0.0010
# Epoch 73/600
# 29/29 [==============================] - 0s 14ms/step - loss: 0.9519 - accuracy: 0.7498 - val_loss: 0.9326 - val_accuracy: 0.7504 - lr: 0.0010
# Epoch 74/600
# 29/29 [==============================] - 0s 9ms/step - loss: 0.8755 - accuracy: 0.7702 - val_loss: 0.8873 - val_accuracy: 0.7586 - lr: 0.0010
# Epoch 75/600
# 29/29 [==============================] - 0s 9ms/step - loss: 0.8558 - accuracy: 0.7785 - val_loss: 0.8604 - val_accuracy: 0.7620 - lr: 0.0010
# Epoch 76/600
# 29/29 [==============================] - 0s 15ms/step - loss: 0.8119 - accuracy: 0.7853 - val_loss: 0.8319 - val_accuracy: 0.7714 - lr: 0.0010
# Epoch 77/600
# 29/29 [==============================] - 0s 9ms/step - loss: 0.8861 - accuracy: 0.7763 - val_loss: 1.0205 - val_accuracy: 0.7294 - lr: 0.0010
# Epoch 78/600
# 29/29 [==============================] - 0s 8ms/step - loss: 0.9565 - accuracy: 0.7388 - val_loss: 0.9546 - val_accuracy: 0.7333 - lr: 0.0010
# Epoch 79/600
# 29/29 [==============================] - 1s 18ms/step - loss: 0.9514 - accuracy: 0.7540 - val_loss: 0.8696 - val_accuracy: 0.7530 - lr: 0.0010
# Epoch 80/600
# 29/29 [==============================] - 0s 9ms/step - loss: 0.7924 - accuracy: 0.7857 - val_loss: 0.8485 - val_accuracy: 0.7581 - lr: 0.0010
# Epoch 81/600
# 29/29 [==============================] - 0s 9ms/step - loss: 0.9950 - accuracy: 0.7524 - val_loss: 1.0277 - val_accuracy: 0.7380 - lr: 0.0010
# Epoch 82/600
# 29/29 [==============================] - 0s 9ms/step - loss: 0.9511 - accuracy: 0.7524 - val_loss: 0.9121 - val_accuracy: 0.7513 - lr: 0.0010
# Epoch 83/600
# 29/29 [==============================] - 0s 9ms/step - loss: 0.8611 - accuracy: 0.7743 - val_loss: 0.8291 - val_accuracy: 0.7830 - lr: 0.0010
# Epoch 84/600
# 29/29 [==============================] - 0s 9ms/step - loss: 0.7783 - accuracy: 0.7897 - val_loss: 0.7859 - val_accuracy: 0.7736 - lr: 0.0010
# Epoch 85/600
# 29/29 [==============================] - 0s 8ms/step - loss: 0.7934 - accuracy: 0.7836 - val_loss: 0.8119 - val_accuracy: 0.7697 - lr: 0.0010
# Epoch 86/600
# 29/29 [==============================] - 0s 10ms/step - loss: 0.7493 - accuracy: 0.7967 - val_loss: 0.7627 - val_accuracy: 0.7972 - lr: 0.0010
# Epoch 87/600
# 29/29 [==============================] - 0s 9ms/step - loss: 0.7184 - accuracy: 0.8138 - val_loss: 0.8246 - val_accuracy: 0.7740 - lr: 0.0010
# Epoch 88/600
# 29/29 [==============================] - 0s 9ms/step - loss: 1.0407 - accuracy: 0.7465 - val_loss: 1.0007 - val_accuracy: 0.7105 - lr: 0.0010
# Epoch 89/600
# 29/29 [==============================] - 0s 8ms/step - loss: 0.8634 - accuracy: 0.7665 - val_loss: 0.8331 - val_accuracy: 0.7762 - lr: 0.0010
# Epoch 90/600
# 29/29 [==============================] - 0s 8ms/step - loss: 0.7801 - accuracy: 0.7932 - val_loss: 0.9415 - val_accuracy: 0.7852 - lr: 0.0010
# Epoch 91/600
# 29/29 [==============================] - 0s 9ms/step - loss: 0.7699 - accuracy: 0.8068 - val_loss: 0.8552 - val_accuracy: 0.7762 - lr: 0.0010
# Epoch 92/600
# 29/29 [==============================] - 0s 9ms/step - loss: 1.1723 - accuracy: 0.7285 - val_loss: 1.1257 - val_accuracy: 0.6955 - lr: 0.0010
# Epoch 93/600
# 29/29 [==============================] - 0s 9ms/step - loss: 1.0520 - accuracy: 0.7267 - val_loss: 0.9265 - val_accuracy: 0.7616 - lr: 0.0010
# Epoch 94/600
# 29/29 [==============================] - 0s 8ms/step - loss: 0.8734 - accuracy: 0.7748 - val_loss: 0.8423 - val_accuracy: 0.7783 - lr: 0.0010
# Epoch 95/600
# 29/29 [==============================] - 0s 9ms/step - loss: 0.8193 - accuracy: 0.7903 - val_loss: 0.8959 - val_accuracy: 0.7736 - lr: 0.0010
# Epoch 96/600
# 29/29 [==============================] - 0s 9ms/step - loss: 0.8176 - accuracy: 0.7930 - val_loss: 0.8220 - val_accuracy: 0.7787 - lr: 0.0010
# Epoch 97/600
# 29/29 [==============================] - 0s 9ms/step - loss: 0.7649 - accuracy: 0.8029 - val_loss: 0.7715 - val_accuracy: 0.7903 - lr: 0.0010
# Epoch 98/600
# 29/29 [==============================] - 0s 9ms/step - loss: 0.7199 - accuracy: 0.8077 - val_loss: 0.7539 - val_accuracy: 0.7950 - lr: 0.0010
# Epoch 99/600
# 29/29 [==============================] - 0s 9ms/step - loss: 0.7020 - accuracy: 0.8129 - val_loss: 0.7623 - val_accuracy: 0.8023 - lr: 0.0010
# Epoch 100/600
# 29/29 [==============================] - 0s 8ms/step - loss: 0.7247 - accuracy: 0.8077 - val_loss: 0.7735 - val_accuracy: 0.7882 - lr: 0.0010
# Epoch 101/600
# 29/29 [==============================] - 0s 9ms/step - loss: 0.6975 - accuracy: 0.8165 - val_loss: 0.7430 - val_accuracy: 0.7950 - lr: 0.0010
# Epoch 102/600
# 29/29 [==============================] - 0s 8ms/step - loss: 0.6666 - accuracy: 0.8206 - val_loss: 0.6861 - val_accuracy: 0.8169 - lr: 0.0010
# Epoch 103/600
# 29/29 [==============================] - 0s 8ms/step - loss: 0.6355 - accuracy: 0.8329 - val_loss: 0.6736 - val_accuracy: 0.8113 - lr: 0.0010
# Epoch 104/600
# 29/29 [==============================] - 0s 8ms/step - loss: 0.6114 - accuracy: 0.8362 - val_loss: 0.8084 - val_accuracy: 0.8126 - lr: 0.0010
# Epoch 105/600
# 29/29 [==============================] - 0s 8ms/step - loss: 0.6637 - accuracy: 0.8283 - val_loss: 0.6630 - val_accuracy: 0.8233 - lr: 0.0010
# Epoch 106/600
# 29/29 [==============================] - 0s 9ms/step - loss: 0.6302 - accuracy: 0.8270 - val_loss: 0.6659 - val_accuracy: 0.8143 - lr: 0.0010
# Epoch 107/600
# 29/29 [==============================] - 0s 9ms/step - loss: 0.6480 - accuracy: 0.8263 - val_loss: 0.6992 - val_accuracy: 0.8027 - lr: 0.0010
# Epoch 108/600
# 29/29 [==============================] - 0s 8ms/step - loss: 0.6570 - accuracy: 0.8316 - val_loss: 0.6864 - val_accuracy: 0.8117 - lr: 0.0010
# Epoch 109/600
# 29/29 [==============================] - 0s 10ms/step - loss: 0.6067 - accuracy: 0.8355 - val_loss: 0.6702 - val_accuracy: 0.8208 - lr: 0.0010
# Epoch 110/600
# 29/29 [==============================] - 0s 8ms/step - loss: 0.5915 - accuracy: 0.8410 - val_loss: 0.7128 - val_accuracy: 0.7937 - lr: 0.0010
# Epoch 111/600
# 29/29 [==============================] - 0s 9ms/step - loss: 0.6098 - accuracy: 0.8381 - val_loss: 0.6682 - val_accuracy: 0.8165 - lr: 0.0010
# Epoch 112/600
# 29/29 [==============================] - 0s 8ms/step - loss: 0.5730 - accuracy: 0.8476 - val_loss: 0.6313 - val_accuracy: 0.8203 - lr: 0.0010
# Epoch 113/600
# 29/29 [==============================] - 0s 9ms/step - loss: 0.5617 - accuracy: 0.8474 - val_loss: 0.5863 - val_accuracy: 0.8431 - lr: 0.0010
# Epoch 114/600
# 29/29 [==============================] - 0s 9ms/step - loss: 0.5385 - accuracy: 0.8574 - val_loss: 0.6147 - val_accuracy: 0.8289 - lr: 0.0010
# Epoch 115/600
# 29/29 [==============================] - 0s 9ms/step - loss: 0.6248 - accuracy: 0.8358 - val_loss: 0.6849 - val_accuracy: 0.8122 - lr: 0.0010
# Epoch 116/600
# 29/29 [==============================] - 0s 8ms/step - loss: 0.6680 - accuracy: 0.8186 - val_loss: 0.6451 - val_accuracy: 0.8173 - lr: 0.0010
# Epoch 117/600
# 29/29 [==============================] - 0s 8ms/step - loss: 0.7288 - accuracy: 0.8184 - val_loss: 0.8077 - val_accuracy: 0.7843 - lr: 0.0010
# Epoch 118/600
# 29/29 [==============================] - 0s 9ms/step - loss: 0.8963 - accuracy: 0.7871 - val_loss: 0.7746 - val_accuracy: 0.7925 - lr: 0.0010
# Epoch 119/600
# 29/29 [==============================] - 0s 9ms/step - loss: 0.7173 - accuracy: 0.8167 - val_loss: 0.7366 - val_accuracy: 0.8190 - lr: 0.0010
# Epoch 120/600
# 29/29 [==============================] - 0s 9ms/step - loss: 0.6328 - accuracy: 0.8335 - val_loss: 0.7087 - val_accuracy: 0.8302 - lr: 0.0010
# Epoch 121/600
# 29/29 [==============================] - 0s 10ms/step - loss: 0.6311 - accuracy: 0.8471 - val_loss: 0.6908 - val_accuracy: 0.8212 - lr: 0.0010
# Epoch 122/600
# 29/29 [==============================] - 0s 9ms/step - loss: 0.5945 - accuracy: 0.8467 - val_loss: 0.6216 - val_accuracy: 0.8375 - lr: 0.0010
# Epoch 123/600
# 29/29 [==============================] - 0s 8ms/step - loss: 0.5417 - accuracy: 0.8590 - val_loss: 0.5995 - val_accuracy: 0.8340 - lr: 0.0010
# Epoch 124/600
# 29/29 [==============================] - 0s 9ms/step - loss: 0.5214 - accuracy: 0.8632 - val_loss: 0.5812 - val_accuracy: 0.8362 - lr: 0.0010
# Epoch 125/600
# 29/29 [==============================] - 0s 8ms/step - loss: 0.5039 - accuracy: 0.8693 - val_loss: 0.5751 - val_accuracy: 0.8418 - lr: 0.0010
# Epoch 126/600
# 29/29 [==============================] - 0s 9ms/step - loss: 0.5003 - accuracy: 0.8702 - val_loss: 0.5640 - val_accuracy: 0.8482 - lr: 0.0010
# Epoch 127/600
# 29/29 [==============================] - 0s 10ms/step - loss: 0.4829 - accuracy: 0.8739 - val_loss: 0.5333 - val_accuracy: 0.8542 - lr: 0.0010
# Epoch 128/600
# 29/29 [==============================] - 0s 9ms/step - loss: 0.5129 - accuracy: 0.8726 - val_loss: 0.5642 - val_accuracy: 0.8486 - lr: 0.0010
# Epoch 129/600
# 29/29 [==============================] - 0s 9ms/step - loss: 0.5060 - accuracy: 0.8667 - val_loss: 0.5795 - val_accuracy: 0.8443 - lr: 0.0010
# Epoch 130/600
# 29/29 [==============================] - 0s 9ms/step - loss: 0.4856 - accuracy: 0.8737 - val_loss: 0.5442 - val_accuracy: 0.8568 - lr: 0.0010
# Epoch 131/600
# 29/29 [==============================] - 0s 9ms/step - loss: 0.4790 - accuracy: 0.8735 - val_loss: 0.5259 - val_accuracy: 0.8658 - lr: 0.0010
# Epoch 132/600
# 29/29 [==============================] - 0s 9ms/step - loss: 0.5552 - accuracy: 0.8616 - val_loss: 0.5926 - val_accuracy: 0.8396 - lr: 0.0010
# Epoch 133/600
# 29/29 [==============================] - 0s 9ms/step - loss: 0.4988 - accuracy: 0.8750 - val_loss: 0.5643 - val_accuracy: 0.8431 - lr: 0.0010
# Epoch 134/600
# 29/29 [==============================] - 0s 10ms/step - loss: 0.4720 - accuracy: 0.8822 - val_loss: 0.5294 - val_accuracy: 0.8585 - lr: 0.0010
# Epoch 135/600
# 29/29 [==============================] - 0s 8ms/step - loss: 0.4436 - accuracy: 0.8860 - val_loss: 0.5261 - val_accuracy: 0.8559 - lr: 0.0010
# Epoch 136/600
# 29/29 [==============================] - 0s 8ms/step - loss: 0.4276 - accuracy: 0.8926 - val_loss: 0.4991 - val_accuracy: 0.8645 - lr: 0.0010
# Epoch 137/600
# 29/29 [==============================] - 0s 8ms/step - loss: 0.4376 - accuracy: 0.8904 - val_loss: 0.5132 - val_accuracy: 0.8593 - lr: 0.0010
# Epoch 138/600
# 29/29 [==============================] - 0s 8ms/step - loss: 0.4311 - accuracy: 0.8886 - val_loss: 0.5023 - val_accuracy: 0.8585 - lr: 0.0010
# Epoch 139/600
# 29/29 [==============================] - 0s 10ms/step - loss: 0.4576 - accuracy: 0.8838 - val_loss: 0.5620 - val_accuracy: 0.8495 - lr: 0.0010
# Epoch 140/600
# 29/29 [==============================] - 0s 8ms/step - loss: 0.5079 - accuracy: 0.8756 - val_loss: 0.5561 - val_accuracy: 0.8486 - lr: 0.0010
# Epoch 141/600
# 29/29 [==============================] - 0s 9ms/step - loss: 0.5076 - accuracy: 0.8789 - val_loss: 0.5533 - val_accuracy: 0.8585 - lr: 0.0010
# Epoch 142/600
# 29/29 [==============================] - 0s 9ms/step - loss: 0.5271 - accuracy: 0.8689 - val_loss: 0.5730 - val_accuracy: 0.8585 - lr: 0.0010
# Epoch 143/600
# 29/29 [==============================] - 0s 9ms/step - loss: 0.5182 - accuracy: 0.8739 - val_loss: 0.5715 - val_accuracy: 0.8546 - lr: 0.0010
# Epoch 144/600
# 29/29 [==============================] - 0s 9ms/step - loss: 0.4844 - accuracy: 0.8816 - val_loss: 0.5280 - val_accuracy: 0.8692 - lr: 0.0010
# Epoch 145/600
# 29/29 [==============================] - 0s 9ms/step - loss: 0.4315 - accuracy: 0.8969 - val_loss: 0.5021 - val_accuracy: 0.8692 - lr: 0.0010
# Epoch 146/600
# 29/29 [==============================] - 0s 9ms/step - loss: 0.4134 - accuracy: 0.9035 - val_loss: 0.4794 - val_accuracy: 0.8739 - lr: 0.0010
# Epoch 147/600
# 29/29 [==============================] - 0s 10ms/step - loss: 0.4328 - accuracy: 0.8897 - val_loss: 0.5251 - val_accuracy: 0.8675 - lr: 0.0010
# Epoch 148/600
# 29/29 [==============================] - 0s 10ms/step - loss: 0.4089 - accuracy: 0.9004 - val_loss: 0.5156 - val_accuracy: 0.8606 - lr: 0.0010
# Epoch 149/600
# 29/29 [==============================] - 0s 9ms/step - loss: 0.3992 - accuracy: 0.9007 - val_loss: 0.5241 - val_accuracy: 0.8632 - lr: 0.0010
# Epoch 150/600
# 29/29 [==============================] - 0s 9ms/step - loss: 0.4007 - accuracy: 0.9015 - val_loss: 0.5906 - val_accuracy: 0.8701 - lr: 0.0010
# Epoch 151/600
# 29/29 [==============================] - 0s 8ms/step - loss: 0.4017 - accuracy: 0.9062 - val_loss: 0.5419 - val_accuracy: 0.8645 - lr: 0.0010
# Epoch 152/600
# 29/29 [==============================] - 0s 8ms/step - loss: 0.4421 - accuracy: 0.8910 - val_loss: 0.5174 - val_accuracy: 0.8692 - lr: 0.0010
# Epoch 153/600
# 29/29 [==============================] - 0s 9ms/step - loss: 0.4119 - accuracy: 0.9051 - val_loss: 0.5120 - val_accuracy: 0.8606 - lr: 0.0010
# Epoch 154/600
# 29/29 [==============================] - 0s 8ms/step - loss: 0.3975 - accuracy: 0.9097 - val_loss: 0.4771 - val_accuracy: 0.8748 - lr: 0.0010
# Epoch 155/600
# 29/29 [==============================] - 0s 10ms/step - loss: 0.3944 - accuracy: 0.9066 - val_loss: 0.4819 - val_accuracy: 0.8731 - lr: 0.0010
# Epoch 156/600
# 29/29 [==============================] - 0s 9ms/step - loss: 0.3947 - accuracy: 0.9050 - val_loss: 0.4541 - val_accuracy: 0.8778 - lr: 0.0010
# Epoch 157/600
# 29/29 [==============================] - 0s 9ms/step - loss: 0.4286 - accuracy: 0.9024 - val_loss: 0.5130 - val_accuracy: 0.8615 - lr: 0.0010
# Epoch 158/600
# 29/29 [==============================] - 0s 9ms/step - loss: 0.6323 - accuracy: 0.8605 - val_loss: 0.6908 - val_accuracy: 0.8362 - lr: 0.0010
# Epoch 159/600
# 29/29 [==============================] - 0s 8ms/step - loss: 0.6291 - accuracy: 0.8579 - val_loss: 0.6479 - val_accuracy: 0.8478 - lr: 0.0010
# Epoch 160/600
# 29/29 [==============================] - 0s 9ms/step - loss: 0.6327 - accuracy: 0.8596 - val_loss: 0.6855 - val_accuracy: 0.8259 - lr: 0.0010
# Epoch 161/600
# 29/29 [==============================] - 0s 8ms/step - loss: 0.7054 - accuracy: 0.8612 - val_loss: 0.7345 - val_accuracy: 0.8285 - lr: 0.0010
# Epoch 162/600
# 29/29 [==============================] - 0s 8ms/step - loss: 0.6610 - accuracy: 0.8507 - val_loss: 0.6484 - val_accuracy: 0.8452 - lr: 0.0010
# Epoch 163/600
# 29/29 [==============================] - 0s 9ms/step - loss: 0.5651 - accuracy: 0.8730 - val_loss: 0.5932 - val_accuracy: 0.8542 - lr: 0.0010
# Epoch 164/600
# 29/29 [==============================] - 0s 9ms/step - loss: 0.5624 - accuracy: 0.8836 - val_loss: 0.6793 - val_accuracy: 0.8418 - lr: 0.0010
# Epoch 165/600
# 29/29 [==============================] - 0s 8ms/step - loss: 0.5499 - accuracy: 0.8796 - val_loss: 0.5770 - val_accuracy: 0.8688 - lr: 0.0010
# Epoch 166/600
# 29/29 [==============================] - 0s 9ms/step - loss: 0.4659 - accuracy: 0.9092 - val_loss: 0.5335 - val_accuracy: 0.8808 - lr: 0.0010
# Epoch 167/600
# 29/29 [==============================] - 0s 9ms/step - loss: 0.4235 - accuracy: 0.9143 - val_loss: 0.4924 - val_accuracy: 0.8864 - lr: 0.0010
# Epoch 168/600
# 29/29 [==============================] - 0s 8ms/step - loss: 0.3959 - accuracy: 0.9175 - val_loss: 0.4592 - val_accuracy: 0.8945 - lr: 0.0010
# Epoch 169/600
# 29/29 [==============================] - 0s 10ms/step - loss: 0.3825 - accuracy: 0.9252 - val_loss: 0.4711 - val_accuracy: 0.8868 - lr: 0.0010
# Epoch 170/600
# 29/29 [==============================] - 0s 10ms/step - loss: 0.3650 - accuracy: 0.9265 - val_loss: 0.4677 - val_accuracy: 0.8885 - lr: 0.0010
# Epoch 171/600
# 29/29 [==============================] - 0s 9ms/step - loss: 0.3779 - accuracy: 0.9228 - val_loss: 0.4966 - val_accuracy: 0.8731 - lr: 0.0010
# Epoch 172/600
# 29/29 [==============================] - 0s 9ms/step - loss: 0.3811 - accuracy: 0.9142 - val_loss: 0.4956 - val_accuracy: 0.8902 - lr: 0.0010
# Epoch 173/600
# 29/29 [==============================] - 0s 10ms/step - loss: 0.3486 - accuracy: 0.9259 - val_loss: 0.4605 - val_accuracy: 0.8851 - lr: 0.0010
# Epoch 174/600
# 29/29 [==============================] - 0s 9ms/step - loss: 0.3580 - accuracy: 0.9221 - val_loss: 0.4508 - val_accuracy: 0.8937 - lr: 0.0010
# Epoch 175/600
# 29/29 [==============================] - 0s 9ms/step - loss: 0.3340 - accuracy: 0.9327 - val_loss: 0.4243 - val_accuracy: 0.8932 - lr: 0.0010
# Epoch 176/600
# 29/29 [==============================] - 0s 9ms/step - loss: 0.3623 - accuracy: 0.9257 - val_loss: 0.4949 - val_accuracy: 0.8718 - lr: 0.0010
# Epoch 177/600
# 29/29 [==============================] - 0s 10ms/step - loss: 0.3748 - accuracy: 0.9197 - val_loss: 0.4215 - val_accuracy: 0.8984 - lr: 0.0010
# Epoch 178/600
# 29/29 [==============================] - 0s 8ms/step - loss: 0.3774 - accuracy: 0.9151 - val_loss: 0.4576 - val_accuracy: 0.8924 - lr: 0.0010
# Epoch 179/600
# 29/29 [==============================] - 0s 9ms/step - loss: 0.3704 - accuracy: 0.9221 - val_loss: 0.4266 - val_accuracy: 0.9001 - lr: 0.0010
# Epoch 180/600
# 29/29 [==============================] - 0s 9ms/step - loss: 0.3287 - accuracy: 0.9327 - val_loss: 0.3837 - val_accuracy: 0.9048 - lr: 0.0010
# Epoch 181/600
# 29/29 [==============================] - 0s 10ms/step - loss: 0.2978 - accuracy: 0.9432 - val_loss: 0.4117 - val_accuracy: 0.8941 - lr: 0.0010
# Epoch 182/600
# 29/29 [==============================] - 0s 9ms/step - loss: 0.3002 - accuracy: 0.9349 - val_loss: 0.3755 - val_accuracy: 0.9014 - lr: 0.0010
# Epoch 183/600
# 29/29 [==============================] - 0s 8ms/step - loss: 0.2753 - accuracy: 0.9447 - val_loss: 0.4082 - val_accuracy: 0.9039 - lr: 0.0010
# Epoch 184/600
# 29/29 [==============================] - 0s 9ms/step - loss: 0.3082 - accuracy: 0.9410 - val_loss: 0.4018 - val_accuracy: 0.8937 - lr: 0.0010
# Epoch 185/600
# 29/29 [==============================] - 0s 8ms/step - loss: 0.3424 - accuracy: 0.9241 - val_loss: 0.4367 - val_accuracy: 0.8816 - lr: 0.0010
# Epoch 186/600
# 29/29 [==============================] - 0s 9ms/step - loss: 0.3321 - accuracy: 0.9320 - val_loss: 0.4184 - val_accuracy: 0.8902 - lr: 0.0010
# Epoch 187/600
# 29/29 [==============================] - 0s 9ms/step - loss: 0.4174 - accuracy: 0.9156 - val_loss: 0.5119 - val_accuracy: 0.8769 - lr: 0.0010
# Epoch 188/600
# 29/29 [==============================] - 0s 9ms/step - loss: 0.5484 - accuracy: 0.8965 - val_loss: 0.6015 - val_accuracy: 0.8859 - lr: 0.0010
# Epoch 189/600
# 29/29 [==============================] - 0s 9ms/step - loss: 0.4346 - accuracy: 0.9191 - val_loss: 0.5846 - val_accuracy: 0.8684 - lr: 0.0010
# Epoch 190/600
# 29/29 [==============================] - 0s 8ms/step - loss: 0.5132 - accuracy: 0.9092 - val_loss: 0.5343 - val_accuracy: 0.8816 - lr: 0.0010
# Epoch 191/600
# 29/29 [==============================] - 0s 8ms/step - loss: 0.4181 - accuracy: 0.9228 - val_loss: 0.5446 - val_accuracy: 0.8894 - lr: 0.0010
# Epoch 192/600
# 29/29 [==============================] - 0s 9ms/step - loss: 0.4001 - accuracy: 0.9267 - val_loss: 0.5219 - val_accuracy: 0.8937 - lr: 0.0010
# Epoch 193/600
# 29/29 [==============================] - 0s 9ms/step - loss: 0.3507 - accuracy: 0.9373 - val_loss: 0.4528 - val_accuracy: 0.9018 - lr: 0.0010
# Epoch 194/600
# 29/29 [==============================] - 0s 8ms/step - loss: 0.3290 - accuracy: 0.9410 - val_loss: 0.4352 - val_accuracy: 0.9095 - lr: 0.0010
# Epoch 195/600
# 29/29 [==============================] - 0s 10ms/step - loss: 0.3086 - accuracy: 0.9439 - val_loss: 0.4408 - val_accuracy: 0.8988 - lr: 0.0010
# Epoch 196/600
# 29/29 [==============================] - 0s 10ms/step - loss: 0.3044 - accuracy: 0.9414 - val_loss: 0.3974 - val_accuracy: 0.9069 - lr: 0.0010
# Epoch 197/600
# 29/29 [==============================] - 0s 9ms/step - loss: 0.2689 - accuracy: 0.9524 - val_loss: 0.3766 - val_accuracy: 0.9181 - lr: 0.0010
# Epoch 198/600
# 29/29 [==============================] - 0s 9ms/step - loss: 0.2919 - accuracy: 0.9478 - val_loss: 0.4005 - val_accuracy: 0.9014 - lr: 0.0010
# Epoch 199/600
# 29/29 [==============================] - 0s 10ms/step - loss: 0.2771 - accuracy: 0.9489 - val_loss: 0.3699 - val_accuracy: 0.9091 - lr: 0.0010
# Epoch 200/600
# 29/29 [==============================] - 0s 9ms/step - loss: 0.2582 - accuracy: 0.9518 - val_loss: 0.3455 - val_accuracy: 0.9164 - lr: 0.0010
# Epoch 201/600
# 29/29 [==============================] - 0s 9ms/step - loss: 0.2842 - accuracy: 0.9478 - val_loss: 0.3860 - val_accuracy: 0.9018 - lr: 0.0010
# Epoch 202/600
# 29/29 [==============================] - 0s 10ms/step - loss: 0.2639 - accuracy: 0.9460 - val_loss: 0.3914 - val_accuracy: 0.9039 - lr: 0.0010
# Epoch 203/600
# 29/29 [==============================] - 0s 9ms/step - loss: 0.2431 - accuracy: 0.9570 - val_loss: 0.3394 - val_accuracy: 0.9164 - lr: 0.0010
# Epoch 204/600
# 29/29 [==============================] - 0s 9ms/step - loss: 0.2491 - accuracy: 0.9517 - val_loss: 0.3711 - val_accuracy: 0.9087 - lr: 0.0010
# Epoch 205/600
# 29/29 [==============================] - 0s 10ms/step - loss: 0.2711 - accuracy: 0.9465 - val_loss: 0.4017 - val_accuracy: 0.8949 - lr: 0.0010
# Epoch 206/600
# 29/29 [==============================] - 0s 9ms/step - loss: 0.2532 - accuracy: 0.9500 - val_loss: 0.3236 - val_accuracy: 0.9254 - lr: 0.0010
# Epoch 207/600
# 29/29 [==============================] - 0s 10ms/step - loss: 0.2371 - accuracy: 0.9531 - val_loss: 0.3615 - val_accuracy: 0.9095 - lr: 0.0010
# Epoch 208/600
# 29/29 [==============================] - 0s 10ms/step - loss: 0.2275 - accuracy: 0.9570 - val_loss: 0.3349 - val_accuracy: 0.9168 - lr: 0.0010
# Epoch 209/600
# 29/29 [==============================] - 0s 9ms/step - loss: 0.2323 - accuracy: 0.9540 - val_loss: 0.3412 - val_accuracy: 0.9185 - lr: 0.0010
# Epoch 210/600
# 29/29 [==============================] - 0s 9ms/step - loss: 0.2279 - accuracy: 0.9581 - val_loss: 0.3761 - val_accuracy: 0.9091 - lr: 0.0010
# Epoch 211/600
# 29/29 [==============================] - 0s 10ms/step - loss: 0.2760 - accuracy: 0.9506 - val_loss: 0.4123 - val_accuracy: 0.9014 - lr: 0.0010
# Epoch 212/600
# 29/29 [==============================] - 0s 10ms/step - loss: 0.2592 - accuracy: 0.9487 - val_loss: 0.3820 - val_accuracy: 0.9117 - lr: 0.0010
# Epoch 213/600
# 29/29 [==============================] - 0s 8ms/step - loss: 0.2295 - accuracy: 0.9583 - val_loss: 0.3783 - val_accuracy: 0.9125 - lr: 0.0010
# Epoch 214/600
# 29/29 [==============================] - 0s 9ms/step - loss: 0.2670 - accuracy: 0.9461 - val_loss: 0.4031 - val_accuracy: 0.9018 - lr: 0.0010
# Epoch 215/600
# 29/29 [==============================] - 0s 9ms/step - loss: 0.3756 - accuracy: 0.9311 - val_loss: 0.7009 - val_accuracy: 0.8512 - lr: 0.0010
# Epoch 216/600
# 29/29 [==============================] - 0s 9ms/step - loss: 1.0142 - accuracy: 0.7985 - val_loss: 0.8306 - val_accuracy: 0.8100 - lr: 0.0010
# Epoch 217/600
# 29/29 [==============================] - 0s 9ms/step - loss: 0.8536 - accuracy: 0.8368 - val_loss: 0.7302 - val_accuracy: 0.8413 - lr: 0.0010
# Epoch 218/600
# 29/29 [==============================] - 0s 9ms/step - loss: 0.6198 - accuracy: 0.8798 - val_loss: 0.6156 - val_accuracy: 0.8735 - lr: 0.0010
# Epoch 219/600
# 29/29 [==============================] - 0s 9ms/step - loss: 0.5112 - accuracy: 0.9039 - val_loss: 0.5519 - val_accuracy: 0.8894 - lr: 0.0010
# Epoch 220/600
# 29/29 [==============================] - 0s 8ms/step - loss: 0.4457 - accuracy: 0.9290 - val_loss: 0.5214 - val_accuracy: 0.8984 - lr: 0.0010
# Epoch 221/600
# 29/29 [==============================] - 0s 9ms/step - loss: 0.4654 - accuracy: 0.9298 - val_loss: 0.6063 - val_accuracy: 0.8761 - lr: 0.0010
# Epoch 222/600
# 29/29 [==============================] - 0s 10ms/step - loss: 0.5714 - accuracy: 0.8985 - val_loss: 0.6144 - val_accuracy: 0.8739 - lr: 0.0010
# Epoch 223/600
# 29/29 [==============================] - 0s 11ms/step - loss: 0.5068 - accuracy: 0.9162 - val_loss: 0.5293 - val_accuracy: 0.8971 - lr: 0.0010
# Epoch 224/600
# 29/29 [==============================] - 0s 9ms/step - loss: 0.4669 - accuracy: 0.9241 - val_loss: 0.5217 - val_accuracy: 0.8885 - lr: 0.0010
# Epoch 225/600
# 29/29 [==============================] - 0s 9ms/step - loss: 0.3877 - accuracy: 0.9406 - val_loss: 0.4553 - val_accuracy: 0.9095 - lr: 0.0010
# Epoch 226/600
# 29/29 [==============================] - 0s 9ms/step - loss: 0.3328 - accuracy: 0.9526 - val_loss: 0.4351 - val_accuracy: 0.9125 - lr: 0.0010
# Epoch 227/600
# 29/29 [==============================] - 0s 10ms/step - loss: 0.3067 - accuracy: 0.9596 - val_loss: 0.4115 - val_accuracy: 0.9202 - lr: 2.0000e-04
# Epoch 228/600
# 29/29 [==============================] - 0s 9ms/step - loss: 0.3008 - accuracy: 0.9634 - val_loss: 0.4016 - val_accuracy: 0.9232 - lr: 2.0000e-04
# Epoch 229/600
# 29/29 [==============================] - 0s 9ms/step - loss: 0.2904 - accuracy: 0.9645 - val_loss: 0.3978 - val_accuracy: 0.9275 - lr: 2.0000e-04
# Epoch 230/600
# 29/29 [==============================] - 0s 9ms/step - loss: 0.2956 - accuracy: 0.9588 - val_loss: 0.3943 - val_accuracy: 0.9262 - lr: 2.0000e-04
# Epoch 231/600
# 29/29 [==============================] - 0s 8ms/step - loss: 0.2814 - accuracy: 0.9636 - val_loss: 0.3821 - val_accuracy: 0.9254 - lr: 2.0000e-04
# Epoch 232/600
# 29/29 [==============================] - 0s 9ms/step - loss: 0.2814 - accuracy: 0.9645 - val_loss: 0.3826 - val_accuracy: 0.9237 - lr: 2.0000e-04
# Epoch 233/600
# 29/29 [==============================] - 0s 10ms/step - loss: 0.2741 - accuracy: 0.9647 - val_loss: 0.3715 - val_accuracy: 0.9267 - lr: 2.0000e-04
# Epoch 234/600
# 29/29 [==============================] - 0s 9ms/step - loss: 0.2671 - accuracy: 0.9680 - val_loss: 0.3703 - val_accuracy: 0.9297 - lr: 2.0000e-04
# Epoch 235/600
# 29/29 [==============================] - 0s 8ms/step - loss: 0.2614 - accuracy: 0.9665 - val_loss: 0.3680 - val_accuracy: 0.9275 - lr: 2.0000e-04
# Epoch 236/600
# 29/29 [==============================] - 0s 9ms/step - loss: 0.2672 - accuracy: 0.9632 - val_loss: 0.3642 - val_accuracy: 0.9267 - lr: 2.0000e-04
# Epoch 237/600
# 29/29 [==============================] - 0s 9ms/step - loss: 0.2559 - accuracy: 0.9669 - val_loss: 0.3617 - val_accuracy: 0.9275 - lr: 2.0000e-04
# Epoch 238/600
# 29/29 [==============================] - 0s 10ms/step - loss: 0.2576 - accuracy: 0.9632 - val_loss: 0.3655 - val_accuracy: 0.9288 - lr: 2.0000e-04
# Epoch 239/600
# 29/29 [==============================] - 0s 9ms/step - loss: 0.2437 - accuracy: 0.9673 - val_loss: 0.3549 - val_accuracy: 0.9267 - lr: 2.0000e-04
# Epoch 240/600
# 29/29 [==============================] - 0s 10ms/step - loss: 0.2426 - accuracy: 0.9689 - val_loss: 0.3550 - val_accuracy: 0.9280 - lr: 2.0000e-04
# Epoch 241/600
# 29/29 [==============================] - 0s 9ms/step - loss: 0.2434 - accuracy: 0.9676 - val_loss: 0.3546 - val_accuracy: 0.9262 - lr: 2.0000e-04
# Epoch 242/600
# 29/29 [==============================] - 0s 10ms/step - loss: 0.2376 - accuracy: 0.9686 - val_loss: 0.3387 - val_accuracy: 0.9292 - lr: 2.0000e-04
# Epoch 243/600
# 29/29 [==============================] - 0s 9ms/step - loss: 0.2423 - accuracy: 0.9691 - val_loss: 0.3381 - val_accuracy: 0.9301 - lr: 2.0000e-04
# Epoch 244/600
# 29/29 [==============================] - 0s 9ms/step - loss: 0.2288 - accuracy: 0.9730 - val_loss: 0.3427 - val_accuracy: 0.9267 - lr: 2.0000e-04
# Epoch 245/600
# 29/29 [==============================] - 0s 9ms/step - loss: 0.2338 - accuracy: 0.9660 - val_loss: 0.3408 - val_accuracy: 0.9262 - lr: 2.0000e-04
# Epoch 246/600
# 29/29 [==============================] - 0s 9ms/step - loss: 0.2292 - accuracy: 0.9700 - val_loss: 0.3350 - val_accuracy: 0.9267 - lr: 2.0000e-04
# Epoch 247/600
# 29/29 [==============================] - 0s 9ms/step - loss: 0.2300 - accuracy: 0.9693 - val_loss: 0.3368 - val_accuracy: 0.9262 - lr: 2.0000e-04
# Epoch 248/600
# 29/29 [==============================] - 0s 9ms/step - loss: 0.2297 - accuracy: 0.9651 - val_loss: 0.3355 - val_accuracy: 0.9267 - lr: 2.0000e-04
# Epoch 249/600
# 29/29 [==============================] - 0s 9ms/step - loss: 0.2221 - accuracy: 0.9684 - val_loss: 0.3263 - val_accuracy: 0.9301 - lr: 2.0000e-04
# Epoch 250/600
# 29/29 [==============================] - 0s 10ms/step - loss: 0.2162 - accuracy: 0.9717 - val_loss: 0.3224 - val_accuracy: 0.9340 - lr: 2.0000e-04
# Epoch 251/600
# 29/29 [==============================] - 0s 9ms/step - loss: 0.2184 - accuracy: 0.9673 - val_loss: 0.3208 - val_accuracy: 0.9340 - lr: 2.0000e-04
# Epoch 252/600
# 29/29 [==============================] - 0s 9ms/step - loss: 0.2177 - accuracy: 0.9702 - val_loss: 0.3152 - val_accuracy: 0.9318 - lr: 2.0000e-04
# Epoch 253/600
# 29/29 [==============================] - 0s 9ms/step - loss: 0.2172 - accuracy: 0.9717 - val_loss: 0.3151 - val_accuracy: 0.9331 - lr: 2.0000e-04
# Epoch 254/600
# 29/29 [==============================] - 0s 10ms/step - loss: 0.2085 - accuracy: 0.9733 - val_loss: 0.3071 - val_accuracy: 0.9370 - lr: 2.0000e-04
# Epoch 255/600
# 29/29 [==============================] - 0s 9ms/step - loss: 0.2064 - accuracy: 0.9721 - val_loss: 0.3192 - val_accuracy: 0.9267 - lr: 2.0000e-04
# Epoch 256/600
# 29/29 [==============================] - 0s 9ms/step - loss: 0.2065 - accuracy: 0.9728 - val_loss: 0.3130 - val_accuracy: 0.9310 - lr: 2.0000e-04
# Epoch 257/600
# 29/29 [==============================] - 0s 9ms/step - loss: 0.2016 - accuracy: 0.9695 - val_loss: 0.3057 - val_accuracy: 0.9335 - lr: 2.0000e-04
# Epoch 258/600
# 29/29 [==============================] - 0s 9ms/step - loss: 0.1950 - accuracy: 0.9757 - val_loss: 0.3013 - val_accuracy: 0.9344 - lr: 2.0000e-04
# Epoch 259/600
# 29/29 [==============================] - 0s 10ms/step - loss: 0.2014 - accuracy: 0.9722 - val_loss: 0.2987 - val_accuracy: 0.9335 - lr: 2.0000e-04
# Epoch 260/600
# 29/29 [==============================] - 0s 8ms/step - loss: 0.1903 - accuracy: 0.9746 - val_loss: 0.2979 - val_accuracy: 0.9331 - lr: 2.0000e-04
# Epoch 261/600
# 29/29 [==============================] - 0s 8ms/step - loss: 0.1932 - accuracy: 0.9721 - val_loss: 0.3082 - val_accuracy: 0.9327 - lr: 2.0000e-04
# Epoch 262/600
# 29/29 [==============================] - 0s 10ms/step - loss: 0.2020 - accuracy: 0.9691 - val_loss: 0.2943 - val_accuracy: 0.9305 - lr: 2.0000e-04
# Epoch 263/600
# 29/29 [==============================] - 0s 10ms/step - loss: 0.1898 - accuracy: 0.9746 - val_loss: 0.2958 - val_accuracy: 0.9297 - lr: 2.0000e-04
# Epoch 264/600
# 29/29 [==============================] - 0s 9ms/step - loss: 0.1896 - accuracy: 0.9733 - val_loss: 0.2944 - val_accuracy: 0.9318 - lr: 2.0000e-04
# Epoch 265/600
# 29/29 [==============================] - 0s 9ms/step - loss: 0.1922 - accuracy: 0.9713 - val_loss: 0.2907 - val_accuracy: 0.9314 - lr: 2.0000e-04
# Epoch 266/600
# 29/29 [==============================] - 0s 9ms/step - loss: 0.1889 - accuracy: 0.9741 - val_loss: 0.2824 - val_accuracy: 0.9374 - lr: 2.0000e-04
# Epoch 267/600
# 29/29 [==============================] - 0s 10ms/step - loss: 0.1761 - accuracy: 0.9765 - val_loss: 0.2885 - val_accuracy: 0.9310 - lr: 2.0000e-04
# Epoch 268/600
# 29/29 [==============================] - 0s 8ms/step - loss: 0.1842 - accuracy: 0.9735 - val_loss: 0.2886 - val_accuracy: 0.9348 - lr: 2.0000e-04
# Epoch 269/600
# 29/29 [==============================] - 0s 10ms/step - loss: 0.1866 - accuracy: 0.9719 - val_loss: 0.2853 - val_accuracy: 0.9331 - lr: 2.0000e-04
# Epoch 270/600
# 29/29 [==============================] - 0s 9ms/step - loss: 0.1744 - accuracy: 0.9756 - val_loss: 0.2753 - val_accuracy: 0.9374 - lr: 2.0000e-04
# Epoch 271/600
# 29/29 [==============================] - 0s 9ms/step - loss: 0.1724 - accuracy: 0.9763 - val_loss: 0.2751 - val_accuracy: 0.9331 - lr: 2.0000e-04
# Epoch 272/600
# 29/29 [==============================] - 0s 8ms/step - loss: 0.1752 - accuracy: 0.9735 - val_loss: 0.2803 - val_accuracy: 0.9340 - lr: 2.0000e-04
# Epoch 273/600
# 29/29 [==============================] - 0s 9ms/step - loss: 0.1671 - accuracy: 0.9759 - val_loss: 0.2773 - val_accuracy: 0.9331 - lr: 2.0000e-04
# Epoch 274/600
# 29/29 [==============================] - 0s 9ms/step - loss: 0.1700 - accuracy: 0.9754 - val_loss: 0.2824 - val_accuracy: 0.9318 - lr: 2.0000e-04
# Epoch 275/600
# 29/29 [==============================] - 0s 9ms/step - loss: 0.1634 - accuracy: 0.9778 - val_loss: 0.2812 - val_accuracy: 0.9314 - lr: 2.0000e-04
# Epoch 276/600
# 29/29 [==============================] - 0s 10ms/step - loss: 0.1678 - accuracy: 0.9732 - val_loss: 0.2836 - val_accuracy: 0.9284 - lr: 2.0000e-04
# Epoch 277/600
# 29/29 [==============================] - 0s 9ms/step - loss: 0.1644 - accuracy: 0.9770 - val_loss: 0.2752 - val_accuracy: 0.9310 - lr: 2.0000e-04
# Epoch 278/600
# 29/29 [==============================] - 0s 9ms/step - loss: 0.1656 - accuracy: 0.9750 - val_loss: 0.2709 - val_accuracy: 0.9357 - lr: 2.0000e-04
# Epoch 279/600
# 29/29 [==============================] - 0s 10ms/step - loss: 0.1683 - accuracy: 0.9737 - val_loss: 0.2800 - val_accuracy: 0.9310 - lr: 2.0000e-04
# Epoch 280/600
# 29/29 [==============================] - 0s 9ms/step - loss: 0.1657 - accuracy: 0.9763 - val_loss: 0.2861 - val_accuracy: 0.9271 - lr: 2.0000e-04
# Epoch 281/600
# 29/29 [==============================] - 0s 9ms/step - loss: 0.1603 - accuracy: 0.9756 - val_loss: 0.2839 - val_accuracy: 0.9271 - lr: 2.0000e-04
# Epoch 282/600
# 29/29 [==============================] - 0s 10ms/step - loss: 0.1642 - accuracy: 0.9752 - val_loss: 0.2978 - val_accuracy: 0.9331 - lr: 2.0000e-04
# Epoch 283/600
# 29/29 [==============================] - 0s 9ms/step - loss: 0.1522 - accuracy: 0.9792 - val_loss: 0.2631 - val_accuracy: 0.9331 - lr: 2.0000e-04
# Epoch 284/600
# 29/29 [==============================] - 0s 10ms/step - loss: 0.1571 - accuracy: 0.9754 - val_loss: 0.2766 - val_accuracy: 0.9335 - lr: 2.0000e-04
# Epoch 285/600
# 29/29 [==============================] - 0s 9ms/step - loss: 0.1709 - accuracy: 0.9717 - val_loss: 0.2971 - val_accuracy: 0.9258 - lr: 2.0000e-04
# Epoch 286/600
# 29/29 [==============================] - 0s 8ms/step - loss: 0.1624 - accuracy: 0.9724 - val_loss: 0.2709 - val_accuracy: 0.9357 - lr: 2.0000e-04
# Epoch 287/600
# 29/29 [==============================] - 0s 9ms/step - loss: 0.1484 - accuracy: 0.9776 - val_loss: 0.2752 - val_accuracy: 0.9348 - lr: 4.0000e-05
# Epoch 288/600
# 29/29 [==============================] - 0s 9ms/step - loss: 0.1510 - accuracy: 0.9781 - val_loss: 0.2725 - val_accuracy: 0.9370 - lr: 4.0000e-05
# Epoch 289/600
# 29/29 [==============================] - 0s 9ms/step - loss: 0.1553 - accuracy: 0.9787 - val_loss: 0.2627 - val_accuracy: 0.9344 - lr: 4.0000e-05
# Epoch 290/600
# 29/29 [==============================] - 0s 9ms/step - loss: 0.1546 - accuracy: 0.9770 - val_loss: 0.2636 - val_accuracy: 0.9348 - lr: 4.0000e-05
# Epoch 291/600
# 29/29 [==============================] - 0s 9ms/step - loss: 0.1468 - accuracy: 0.9794 - val_loss: 0.2605 - val_accuracy: 0.9344 - lr: 4.0000e-05
# Epoch 292/600
# 29/29 [==============================] - 0s 10ms/step - loss: 0.1514 - accuracy: 0.9794 - val_loss: 0.2591 - val_accuracy: 0.9344 - lr: 4.0000e-05
# Epoch 293/600
# 29/29 [==============================] - 0s 10ms/step - loss: 0.1467 - accuracy: 0.9803 - val_loss: 0.2606 - val_accuracy: 0.9340 - lr: 4.0000e-05
# Epoch 294/600
# 29/29 [==============================] - 0s 8ms/step - loss: 0.1511 - accuracy: 0.9779 - val_loss: 0.2575 - val_accuracy: 0.9344 - lr: 4.0000e-05
# Epoch 295/600
# 29/29 [==============================] - 0s 10ms/step - loss: 0.1505 - accuracy: 0.9790 - val_loss: 0.2575 - val_accuracy: 0.9340 - lr: 4.0000e-05
# Epoch 296/600
# 29/29 [==============================] - 0s 9ms/step - loss: 0.1529 - accuracy: 0.9770 - val_loss: 0.2536 - val_accuracy: 0.9365 - lr: 4.0000e-05

# %%
# Save the model
model.save('model_1D_CNN')

# %%
#Plot the history of the losses: training vs validation
best_epoch = np.argmax(history['val_accuracy'])
plt.figure(figsize=(17,4))
plt.plot(history['loss'], label='Training loss', alpha=.8, color='#ff7f0e')
plt.plot(history['val_loss'], label='Validation loss', alpha=.9, color='#5a9aa5')
plt.axvline(x=best_epoch, label='Best epoch', alpha=.3, ls='--', color='#5a9aa5')
plt.title('Categorical Crossentropy')
plt.legend()
plt.grid(alpha=.3)
plt.show()

#Plot the history of the accuracy: training vs validation
plt.figure(figsize=(17,4))
plt.plot(history['accuracy'], label='Training accuracy', alpha=.8, color='#ff7f0e')
plt.plot(history['val_accuracy'], label='Validation accuracy', alpha=.9, color='#5a9aa5')
plt.axvline(x=best_epoch, label='Best epoch', alpha=.3, ls='--', color='#5a9aa5')
plt.title('Accuracy')
plt.legend()
plt.grid(alpha=.3)
plt.show()

# %%
# Prediction of the labels on the test set and accuracy
predictions = model.predict(x_test)
accuracy = accuracy_score(np.argmax(y_test, axis=-1), np.argmax(predictions, axis=-1))
print(accuracy)
# Out:
# 16/16 [==============================] - 0s 3ms/step
# 0.7407407407407407

# %%
# Compute the confusion matrix
cm = confusion_matrix(np.argmax(y_test, axis=-1), np.argmax(predictions, axis=-1))

# Compute the classification metrics
accuracy = accuracy_score(np.argmax(y_test, axis=-1), np.argmax(predictions, axis=-1))
precision = precision_score(np.argmax(y_test, axis=-1), np.argmax(predictions, axis=-1), average='macro')
recall = recall_score(np.argmax(y_test, axis=-1), np.argmax(predictions, axis=-1), average='macro')
f1 = f1_score(np.argmax(y_test, axis=-1), np.argmax(predictions, axis=-1), average='macro')
print('Accuracy:',accuracy.round(4))
print('Precision:',precision.round(4))
print('Recall:',recall.round(4))
print('F1:',f1.round(4))

# Plot the confusion matrix
plt.figure(figsize=(10,8))
sns.heatmap(cm.T, cmap='Blues', xticklabels={"0","1","2","3","4","6","7","8","9","10","11"}, yticklabels={"0","1","2","3","4","6","7","8","9","10","11"},annot=True)
plt.xlabel('True labels')
plt.ylabel('Predicted labels')
plt.show()
# Out:
# Accuracy: 0.7407
# Precision: 0.7267
# Recall: 0.6655
# F1: 0.6866
